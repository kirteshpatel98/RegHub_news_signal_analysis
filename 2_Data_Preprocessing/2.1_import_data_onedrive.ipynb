# %%
import base64
import pandas as pd
import numpy as np

# %%
def create_onedrive_directdownload(onedrive_link):
    data_bytes64 = base64.b64encode(bytes(onedrive_link, 'utf-8'))
    data_bytes64_String = data_bytes64.decode('utf-8').replace('/','_').replace('+','-').rstrip("=")
    resultUrl = f"https://api.onedrive.com/v1.0/shares/u!{data_bytes64_String}/root/content"
    return resultUrl

# %%
onedrive_link='https://1drv.ms/u/s!AoiE7xOoBAsngsgTerpuaYKsupEgYA?e=vctydO'
onedrive_direct_link=create_onedrive_directdownload(onedrive_link)
onedrive_direct_link
# Out:
# 'https://api.onedrive.com/v1.0/shares/u!aHR0cHM6Ly8xZHJ2Lm1zL3UvcyFBb2lFN3hPb0JBc25nc2dUZXJwdWFZS3N1cEVnWUE_ZT12Y3R5ZE8/root/content'

# %%
df=pd.read_csv(onedrive_direct_link)
df
# Out:
#                                  _id           _index  _score _type concepts  \
# 0     FinenfreiPresostenfrei12884764  2021_reghub_new     NaN  _doc      NaN
# 1       focScholzPresid217207826html  2021_reghub_new     NaN  _doc      NaN
# 2       merngnisPresente92556026html  2021_reghub_new     NaN  _doc      NaN
# 3        maretBeatPresfiling20231003  2021_reghub_new     NaN  _doc      NaN
# 4      AlllationPres202310030398html  2021_reghub_new     NaN  _doc      NaN
# ...                              ...              ...     ...   ...      ...
# 4766   berWochePresommerzbanka382003  2021_reghub_new     NaN  _doc      NaN
# 4767   finztreffStocuebergeben319151  2021_reghub_new     NaN  _doc      NaN
# 4768    boersedeStocageLinie34924557  2021_reghub_new     NaN  _doc      NaN
# 4769    monneywebPrestrustagencysays  2021_reghub_new     NaN  _doc      NaN
# 4770     ftgsaysPresb48f0f767522d802  2021_reghub_new     NaN  _doc      NaN
#
#      found_dates                              id internal_links keywords  \
# 0             []  FinenfreiPresostenfrei12884764             []      NaN
# 1             []    focScholzPresid217207826html             []      NaN
# 2             []    merngnisPresente92556026html             []      NaN
# 3             []     maretBeatPresfiling20231003             []      NaN
# 4             []   AlllationPres202310030398html             []      NaN
# ...          ...                             ...            ...      ...
# 4766          []   berWochePresommerzbanka382003             []      NaN
# 4767          []   finztreffStocuebergeben319151             []      NaN
# 4768          []    boersedeStocageLinie34924557             []      NaN
# 4769          []    monneywebPrestrustagencysays             []      NaN
# 4770          []     ftgsaysPresb48f0f767522d802             []      NaN
#
#      language  ...                                       news_summary  \
# 0          de  ...  The article discusses how a fortunate man with...
# 1          en  ...  The article discusses how M.M. Warburg may hav...
# 2          en  ...  The Cologne Prosecutor's Office accuses German...
# 3          en  ...  Deutsche Bank AG has acquired an additional 49...
# 4          en  ...  Mozambique has reached a negotiated agreement ...
# ...       ...  ...                                                ...
# 4766       de  ...  Commerzbank: In Friedrichshagen hat ein neuer ...
# 4767       de  ...  Der DAX hat am Freitag ein neues Rekordhoch er...
# 4768       de  ...  Mit dem Rücksetzer auf 990 EUR hat die Commerz...
# 4769       en  ...  The Competition and Markets Authority said Cit...
# 4770       en  ...  Follow the topics in this article. Gilts. Add ...
#
#                                              news_title  \
# 0     Tradingaktion mit comdirect  Handeln Sie Socié...
# 1     CumExAffäre: Brisante Tagebucheinträge belaste...
# 2     CumExAffäre: Dokumente bringen Scholz offenbar...
# 3     K.J. Harrison & Partners Inc Boosts Stake in C...
# 4       Mozambique: Govt Wins Massive Debt Cancellation
# ...                                                 ...
# 4766  Neu eröffnet: Commerzbank  Friedrichshagen  Be...
# 4767  ROUNDUP: AirbusJubiläum in Hamburg  600. Flugz...
# 4768      CommerzbankAktie unter 38TageLinie  boerse.de
# 4769  Five major banks colluded on UK bonds antitrus...
# 4770  Five banks broke competition law over UK gover...
#
#                                              news_topic       news_type  \
# 0     [{"description":"Online Banken und Vermögensve...  Press releases
# 1     [{"description":"M.M. Warburg","relevance":12,...  Press releases
# 2     [{"description":"M.M. Warburg","relevance":6,"...  Press releases
# 3     [{"description":"Deutsche Bank","relevance":6,...  Press releases
# 4     [{"description":"Financial Crime","relevance":...  Press releases
# ...                                                 ...             ...
# 4766  [{"description":"Commerzbank AG","relevance":2...  Press releases
# 4767  [{"description":"Commerzbank AG","relevance":6...  Stock Analysis
# 4768  [{"description":"Commerzbank AG","relevance":2...  Stock Analysis
# 4769  [{"description":"Deutsche Bank","relevance":6,...  Press releases
# 4770  [{"description":"Compliance","relevance":6,"co...  Press releases
#
#       references  sentiment_label sentiment_score  source_country  \
# 0             []              NaN             0.0         Germany
# 1             []              NaN             0.0          Global
# 2             []              NaN             0.0          Global
# 3             []              NaN             0.0          Global
# 4             []              NaN             0.0          Africa
# ...          ...              ...             ...             ...
# 4766          []              NaN             0.0          Global
# 4767          []              NaN             0.0          Global
# 4768          []              NaN             0.0          Global
# 4769          []              NaN             0.0          Global
# 4770          []              NaN             0.0          Global
#
#             source_name           source_type
# 0          Finanzen.net  Information Provider
# 1              focus.de  Information Provider
# 2             merkur.de  Information Provider
# 3        marketbeat.com  Information Provider
# 4             AllAfrica  Information Provider
# ...                 ...                   ...
# 4766  berliner-woche.de  Information Provider
# 4767     finanztreff.de  Information Provider
# 4768          boerse.de  Information Provider
# 4769     moneyweb.co.za  Information Provider
# 4770             ft.com  Information Provider
#
# [4771 rows x 28 columns]
