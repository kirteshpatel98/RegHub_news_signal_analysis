# %%
import base64
import pandas as pd
import numpy as np

# %%
def create_onedrive_directdownload(onedrive_link):
    data_bytes64 = base64.b64encode(bytes(onedrive_link, 'utf-8'))
    data_bytes64_String = data_bytes64.decode('utf-8').replace('/','_').replace('+','-').rstrip("=")
    resultUrl = f"https://api.onedrive.com/v1.0/shares/u!{data_bytes64_String}/root/content"
    return resultUrl

# %%
onedrive_link='https://1drv.ms/x/s!AoiE7xOoBAsngsgjcYJ-9Gc78L96rg?e=X3Nujh'
onedrive_direct_link=create_onedrive_directdownload(onedrive_link)
onedrive_direct_link
# Out:
# 'https://api.onedrive.com/v1.0/shares/u!aHR0cHM6Ly8xZHJ2Lm1zL3gvcyFBb2lFN3hPb0JBc25nc2dqY1lKLTlHYzc4TDk2cmc_ZT1YM051amg/root/content'

# %%
df=pd.read_csv(onedrive_direct_link)
df
# Out:
#               personnel      product collaboration      legal
# 0                 staff      product          deal        law
# 1             employees     products           m&a    lawsuit
# 2             workforce    offerings   collaborate      legal
# 3               workers        goods        merged       fine
# 4                labour  merchandise      acquired  vergleich
# ..                  ...          ...           ...        ...
# 56           applicants          NaN           NaN        NaN
# 57  Personalentwicklung          NaN           NaN        NaN
# 58   Beschäftigungsrate          NaN           NaN        NaN
# 59             Kollegen          NaN           NaN        NaN
# 60          Arbeitsteam          NaN           NaN        NaN
#
# [61 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['_id', '_index', '_score', '_type', 'concepts', 'found_dates', 'id',
#        'internal_links', 'keywords', 'language', 'news_author', 'news_content',
#        'news_date', 'news_label', 'news_last_updated', 'news_legalinforce',
#        'news_link', 'news_rank', 'news_summary', 'news_title', 'news_topic',
#        'news_type', 'references', 'sentiment_label', 'sentiment_score',
#        'source_country', 'source_name', 'source_type'],
#       dtype='object')

# %%
df['news_label'].unique()
# Out:
# array([nan, 'curated'], dtype=object)

# %%
df.drop(['_index','_score','_type','concepts','id','internal_links','news_author','news_last_updated','news_legalinforce','news_link','references','source_name'],axis=1,inplace=True)
df
# Out:
#                                  _id found_dates keywords language  \
# 0     FinenfreiPresostenfrei12884764          []      NaN       de
# 1       focScholzPresid217207826html          []      NaN       en
# 2       merngnisPresente92556026html          []      NaN       en
# 3        maretBeatPresfiling20231003          []      NaN       en
# 4      AlllationPres202310030398html          []      NaN       en
# ...                              ...         ...      ...      ...
# 4766   berWochePresommerzbanka382003          []      NaN       de
# 4767   finztreffStocuebergeben319151          []      NaN       de
# 4768    boersedeStocageLinie34924557          []      NaN       de
# 4769    monneywebPrestrustagencysays          []      NaN       en
# 4770     ftgsaysPresb48f0f767522d802          []      NaN       en
#
#                                            news_content  \
# 0     The article discusses how a fortunate man with...
# ...
