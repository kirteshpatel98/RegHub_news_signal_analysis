# %%
# Raw data from RegHub, with minor cleaning
# Combined with ChatGPT keywords
Legal_documents_initial = list(set(["regulation","regulations","order","Commission Implementing Decision",
                  "act","comission decision","amendment","directive","rule","rts",
                  "technical specification","Council Framework Decision","richtlinie",
                  "verordnung","regulatory technical standards","regulatory specification",
                  "legislation","gesetz", 
                   ] + ["regulation","regulations","order","Commission Implementing Decision",
                  "act","comission decision","amendment","directive","rule","rts",
                  "technical specification","Council Framework Decision","richtlinie",
                  "verordnung","regulatory technical standards","regulatory specification",
                  "legislation","gesetz","statute","statutes","law","laws","legislative act",
                  "legal code","legal instrument","legal provision","legal ruling","legal measure",
                  "code of law","legal decree","legal guideline","legal ordinance","legal requirement",
                  "legal rule","legal statute","legally binding document","juridical decision",
                  "government order","official regulation","executive order","decretal",
                  "bylaw","statutory law","legal edict","mandate","judicial ruling",
                  "enactment","norm","code","written law","constitutional provision",
                  "legal framework","legal stipulation","legal clause","judicial decree",
                  "judicial decision","administrative regulation","presidential decree",
                  "public law","private law","case law","court ruling","legal ruling","edict",
                  "fiat","ordinance","prescription","lawmaking","legal instrumentality",
                  "constitutional law","legal precept","judicial ruling","executive decree",
                  "enabling act","codification","ruling","stipulation","subpoena","warrant",
                  "decree-law","legal mandate","proclamation","order in council","decretum",
                  "fiat","authoritative order","government regulation","parliamentary act",
                  "municipal law","règlement","legally enforceable code","act of parliament",
                  "legal policy","constitutional provision","public regulation","judicial act",
                  "resolution","presidential order","royal decree","enabling statute",
                  "government legislation","municipal regulation","statutory regulation",
                  "law of the land","constituent decree","mandamus","legislative enactment",
                  "judicial ordinance","executive ruling","enabling legislation","implementing regulation",
                  "substantive law","procedural law","legislative measure","presidential directive",
                  "order of business","executive action","judicial legislation","legal decision",
                  "government decree","enactment of law","legally mandated provision",
                  "judicial code","constitutional directive","authoritative ruling","decretive law",
                  "edictum","juridical ruling","municipal ordinance","parliamentary resolution",
                  "decretory law","jurisprudence","legal norm","public order","executive regulation",
                  "subordinate legislation","lawmaking body","court decree","juridical decision",
                  "constituent enactment","decretive ruling","règlementation","legally binding rule",
                  "governmental order","ordinance of law","enabling regulation","decretal law",
                  "judicial fiat","governmental decree","reglementation","court mandate",
                  "substantive legislation","judicial provision","implementing directive",
                  "legal framework","court order","judicial edict","legal precedent","statutory rule",
                  "rule of law","mandated provision","legal guideline","normative act","lawmaking process",
                  "regulative law","judicial pronouncement","legally mandated rule","codified law",
                  "rule of order","governmental ordinance","normative regulation","judicial guideline",
                  "constitutional statute","presidential proclamation","public decree","legislative decree",
                  "enabling regulation","judicial legislation","governmental ruling","legal stipulation",
                  "municipal statute","legislative provision","judicial law","legally prescribed rule",
                  "executive legislation","legal provisionality","legislative guideline","governmental act",
                  "judicial enactment","regulatory law","governmental legislation","parliamentary order",
                  "constitutional enactment","judicial decree","decretive ordinance","municipal law",
                  "legal command","judicial prescription","constitutional regulation","legal foundation",
                  "legal edictum","judicial instrument","governmental directive","legislative pronouncement",
                  "municipal ruling","judicial code","regulative provision","executive enactment",
                  "presidential ordinance","judicial provisionality","legally mandated stipulation",
                  "governmental code","judicial rule","parliamentary regulation","legal enactment",
                  "legislative ordinance","judicial legislation","statutory provision","legal framework",
                  "governmental proclamation","judicial measure","decretive ruling","legal legislation",
                  "presidential regulation","municipal code","legally mandated regulation",
                  "judicial precedent","governmental proclamation","enabling provision","legislative fiat",
                  "judicial foundation","municipal decree","presidential legislation","decretive mandate",
                  "legal code","governmental ordinance","judicial regulation","constituent ordinance",
                  "enabling code","legal stipulative","judicial stipulative","presidential provision",
                  "legislative edict","governmental ruling","judicial pronouncement","executive law",
                  "legislative fiat","parliamentary decree","judicial fiat","constitutional directive",
                  "presidential ordinance","legal regulatory","judicial regulatory","legislative regulatory",
                  "governmental regulatory","presidential regulatory","municipal regulatory","decretive regulatory",
                  "judicial regulatory","executive regulatory","constitutional regulatory","parliamentary regulatory",
                  "legal regulatory measure","judicial regulatory measure","legislative regulatory measure",
                  "governmental regulatory measure","presidential regulatory measure","municipal regulatory measure",
                  "decretive regulatory measure","judicial regulatory measure","executive regulatory measure",
                  "constitutional regulatory measure","parliamentary regulatory measure","legal regulatory provision",
                  "judicial regulatory provision","legislative regulatory provision","governmental regulatory provision",
                  "presidential regulatory provision","municipal regulatory provision","decretive regulatory provision",
                  "judicial regulatory provision","executive regulatory provision","constitutional regulatory provision",
                  "parliamentary regulatory provision","Rechtsvorschrift","Gesetzgebung","Rechtsakt","Rechtsvorschriften",
                  "Gesetze","gesetzlicher Code","Rechtsinstrument","Rechtsvorschrift","Rechtsmaßnahme",
                  "Gesetzeskodex","gesetzliche Verordnung","gesetzliche Richtlinie","Gesetzgebung",
                  "Rechtsrahmen","gesetzliche Bestimmung","Gerichtsentscheidung","Verwaltungsverordnung",
                  "gesetzliche Regelung","Rechtsurteil","Gesetzeskodifikation","Richtlinie","Verordnung",
                  "gesetzliche Norm","staatliches Recht","Privatrecht","Rechtsprechung","Rechtssatz",
                  "Gerichtsbeschluss","Rechtsverordnung","Gesetzeserlass","gesetzlicher Leitfaden",
                  "Verordnung der Regierung","municipal Recht","Rechtsvorschriften","gesetzliche Regelung",
                  "Rechtsentscheidung","Rechtsverordnung","gesetzliche Regelung","Rechtsvorschrift",
                  "Rechtsvorschriften","Rechtsinstrument","gesetzliche Richtlinie","Gesetzeskodex",
                  "gesetzliche Verordnung","Rechtsmaßnahme","Rechtsrahmen","gesetzliche Bestimmung",
                  "Gerichtsentscheidung","Verwaltungsverordnung","gesetzliche Regelung","Rechtsurteil",
                  "Gesetzeskodifikation","Richtlinie","Verordnung","gesetzliche Norm","staatliches Recht",
                  "Privatrecht","Rechtsprechung","Rechtssatz","Gerichtsbeschluss","Rechtsverordnung",
                  "Gesetzeserlass","gesetzlicher Leitfaden","Verordnung der Regierung","municipal Recht"]))

Warnings_Enforcements_Sanctions_initial = list(set(["Fine","accuse","fined","fines","Milliardenbusse",
                                  "lawsuite","Strafe","Warnung","Sanction","Sanctions","Sanktions",
                                  "schadenersatzanspruch","schadenersatzansprüche","schadenersatz verurteilt",
                                  "Sanktionen","richterliche entscheidung","juristische entscheidung",
                                  "gerichtliche","is not authorised to","administrative fine",
                                  "disciplinary fine","unlawful use of","has not granted",
                                  "launches investigation","Sanktion","Bafin investigates",
                                  "has not been granted authorisation","without our authorisation",
                                  "keine Erlaubnis nach dem","unerbetene Anrufe","prohibits unauthorised",
                                  "unauthorised provision","unterliegt nicht der Aufsicht","withdrawal",
                                  "unlicenced entity","fines","breaches","verstoß","verstöße",
                                  "suspends","verstösse","Strafe","unauthorised business","ermittelt gegen",
                                  "Strafmaßnahme","suspension of trading","Warning","untersagt die unerlaubt",
                                  "Sanction","Enforcement","Achtung!","Vollstreckung","Sanktionsmaßnahme",
                                  "Durchsetzung","warnt Anleger","Betroffene","mögliche Nachteile",
                                  "verhängt Sanktion","Kundmachung","Öffentlichkeit informieren"
                                   ] + ["Fine","accuse","fined","fines","Milliardenbusse",
                                    "lawsuite","Strafe","Warnung","Sanction","Sanctions","Sanktions",
                                    "schadenersatzanspruch","schadenersatzansprüche","schadenersatz verurteilt",
                                    "Sanktionen","richterliche entscheidung","juristische entscheidung",
                                    "gerichtliche","is not authorised to","administrative fine",
                                    "disciplinary fine","unlawful use of","has not granted",
                                    "launches investigation","Sanktion","Bafin investigates",
                                    "has not been granted authorisation","without our authorisation",
                                    "keine Erlaubnis nach dem","unerbetene Anrufe","prohibits unauthorised",
                                    "unauthorised provision","unterliegt nicht der Aufsicht","withdrawal",
                                    "unlicenced entity","fines","breaches","verstoß","verstöße",
                                    "suspends","verstösse","Strafe","unauthorised business","ermittelt gegen",
                                    "Strafmaßnahme","suspension of trading","Warning","untersagt die unerlaubt",
                                    "Sanction","Enforcement","Achtung!","Vollstreckung","Sanktionsmaßnahme",
                                    "Durchsetzung","warnt Anleger","Betroffene","mögliche Nachteile",
                                    "verhängt Sanktion","Kundmachung","Öffentlichkeit informieren",
                                    "Bußgeld","anklagen","bußgeld","geldstrafe","milliardenstrafe",
                                    "prozess","strafgebühr","strafrechtlich","strafrechtliche verfolgung",
                                    "verurteilung","sanktionierung","strafmassnahme","strafverfolgung",
                                    "strafverfahren","geldbusse","gesetzesverstoß","gesetzwidrige nutzung",
                                    "untersuchung einleiten","aufsichtsbehörde verhängt",
                                    "disziplinarische geldstrafe","nicht befugt zu","hat keine genehmigung erteilt",
                                    "keine genehmigung erteilt","keine befugnis nach dem","unerlaubte geschäfte",
                                    "untersuchung einleiten","behördliche geldstrafe","disziplinarische geldstrafe",
                                    "rechtswidrige nutzung","hat keine erteilt","untersuchung einleiten",
                                    "keine genehmigung erteilt","keine befugnis nach dem","unerlaubte geschäfte",
                                    "unerlaubte provision","nicht der aufsicht unterliegt","rücknahme",
                                    "nicht lizenziertes unternehmen","bußgeld","verstöße","gesetzesverstoß",
                                    "verstoß gegen","sanktion","verstöße gegen","strafe","unerlaubtes geschäft",
                                    "ermittelt gegen","strafmaßnahme","handelsaussetzung","warnung",
                                    "untersagt die unerlaubte","sanktion","durchsetzung","achtung",
                                    "vollstreckung","sanktionsmaßnahme","durchsetzung","warnt anleger",
                                    "betroffene","mögliche nachteile","verhängt sanktion","kundmachung",
                                    "öffentlichkeit informieren","bußgeld","anklagen","bußgeld","geldstrafe",
                                    "milliardenstrafe","prozess","strafgebühr","strafrechtlich","strafrechtliche verfolgung",
                                    "verurteilung","sanktionierung","strafmassnahme","strafverfolgung",
                                    "strafverfahren","geldbusse","gesetzesverstoß","gesetzwidrige nutzung",
                                    "untersuchung einleiten","aufsichtsbehörde verhängt",
                                    "disziplinarische geldstrafe","nicht befugt zu","hat keine genehmigung erteilt",
                                    "keine genehmigung erteilt","keine befugnis nach dem","unerlaubte geschäfte",
                                    "untersuchung einleiten","behördliche geldstrafe","disziplinarische geldstrafe",
                                    "rechtswidrige nutzung","hat keine erteilt","untersuchung einleiten",
                                    "keine genehmigung erteilt","keine befugnis nach dem","unerlaubte geschäfte",
                                    "unerlaubte provision","nicht der aufsicht unterliegt","rücknahme",
                                    "nicht lizenziertes unternehmen","bußgeld","verstöße","gesetzesverstoß",
                                    "verstoß gegen","sanktion","verstöße gegen","strafe","unerlaubtes geschäft",
                                    "ermittelt gegen","strafmaßnahme","handelsaussetzung","warnung",
                                    "untersagt die unerlaubte","sanktion","durchsetzung","achtung",
                                    "vollstreckung","sanktionsmaßnahme","durchsetzung","warnt anleger",
                                    "betroffene","mögliche nachteile","verhängt sanktion","kundmachung",
                                    "öffentlichkeit informieren"]))

Science_papers_initial = list(set(["issues alert","whitepaper","working paper","white paper","wissenschaftlicher artikel",
                 "wissenschaftliche publikation","studie","study","wissenschaftlicher aufsatz",
                 "essay","studie:","wissenschaftliche publikation","science paper","wissenschaftliche Abhandlung",
                 "wissenschaftliche Arbeit","publikation"
                 ] + ["issues alert","whitepaper","working paper","white paper","wissenschaftlicher artikel",
                 "wissenschaftliche publikation","studie","study","wissenschaftlicher aufsatz",
                 "essay","studie:","wissenschaftliche publikation","science paper","wissenschaftliche Abhandlung",
                 "wissenschaftliche Arbeit","publikation","Forschungspapier","Forschungsarbeit",
                 "wissenschaftlicher Bericht","Fachartikel","Fachbeitrag","Fachzeitschriftenartikel",
                 "wissenschaftlicher Beitrag","Forschungsstudie","wissenschaftliche Zeitschrift",
                 "Forschungsdokument","wissenschaftlicher Text","wissenschaftlicher Aufsatz","Forschungspublikation",
                 "wissenschaftlicher Report","Wissenschaftsartikel","Fachpublikation","Fachzeitschrift",
                 "wissenschaftliches Journal","wissenschaftliches Magazin","Forschungsdokumentation",
                 "wissenschaftliche Dokumentation","wissenschaftlicher Essay","wissenschaftliches Essay",
                 "wissenschaftliches Manuskript","wissenschaftlicher Beitrag","wissenschaftlicher Text",
                 "wissenschaftliches Werk","Forschungsschrift","Forschungsergebnisse","Fachforschung",
                 "wissenschaftliche Literatur","Forschungsbeitrag","wissenschaftliche Schriften",
                 "Fachpublikationen","wissenschaftliche Berichte","Forschungsabhandlung",
                 "wissenschaftliche Erkenntnisse","wissenschaftliche Ergebnisse","wissenschaftlicher Diskurs",
                 "Forschungsaufsatz","Fachliteratur","wissenschaftliche Veröffentlichung",
                 "wissenschaftliche Zeitschrift","Forschungsaufzeichnung","wissenschaftliche Analysen",
                 "wissenschaftliche Beiträge","wissenschaftliche Diskussion","wissenschaftliche Fachzeitschrift",
                 "wissenschaftliche Fachpublikation","wissenschaftliche Konferenzbeiträge",
                 "wissenschaftliche Untersuchung","Forschungsbereicht","wissenschaftliche Bewertung",
                 "wissenschaftliche Präsentation","wissenschaftlicher Überblick","Fachdiskussion",
                 "wissenschaftliche Zusammenfassung","wissenschaftliches Symposium",
                 "wissenschaftliche Konferenz","wissenschaftliches Review","wissenschaftliches Journal",
                 "wissenschaftliche Forschung","wissenschaftliches Review","wissenschaftliches Magazin",
                 "wissenschaftliche Untersuchungen","Fachtagung","wissenschaftlicher Fortschritt",
                 "wissenschaftliche Diskussionen","Fachtagung","wissenschaftliche Analyse",
                 "wissenschaftliches Kolloquium","wissenschaftliche Veröffentlichungen",
                 "Forschungsbereiche","wissenschaftliche Fachliteratur","wissenschaftliche Erkenntnisse",
                 "wissenschaftlicher Konsens","wissenschaftliche Publikationsreihe","wissenschaftliche Reviews",
                 "wissenschaftlicher Fortschritt","wissenschaftliche Übersicht","Fachzeitschriftartikel",
                 "wissenschaftliche Fortschritte","wissenschaftliche Literaturübersicht","wissenschaftliche Debatte",
                 "wissenschaftliche Fachliteratur","wissenschaftliche Redaktion","wissenschaftliche Herausgabe",
                 "wissenschaftliche Verlagsarbeit","Forschungsthemen","wissenschaftlicher Dialog",
                 "wissenschaftliche Tagung","wissenschaftlicher Meinungsaustausch","wissenschaftliche Erklärung",
                 "wissenschaftliche Interpretation","wissenschaftliche Forschungsergebnisse","Forschungspublikationen",
                 "wissenschaftlicher Rundblick","Forschungsmethoden","wissenschaftliche Perspektiven",
                 "wissenschaftliche Schreibweise","Forschungsergebnisse veröffentlichen",
                 "wissenschaftliche Beobachtung","wissenschaftliche Kritik","wissenschaftliche Redaktion",
                 "wissenschaftliche Monografie","Forschungsanalyse","wissenschaftliche Diskussionsrunde",
                 "wissenschaftliche Abhandlungen","wissenschaftliche Interpretationen","wissenschaftliche Recherche",
                 "wissenschaftliche Schrift","Forschungsüberblick","wissenschaftlicher Dialog",
                 "wissenschaftliche Konferenzen","wissenschaftliche Zusammenarbeit","wissenschaftliche Community",
                 "wissenschaftliche Literaturkritik","Forschungsausblick","wissenschaftlicher Artikel",
                 "wissenschaftliche Aufzeichnungen","wissenschaftliche Veröffentlichungspolitik",
                 "wissenschaftlicher Forschungsbericht","wissenschaftliche Zitate","Forschungsfeld",
                 "wissenschaftliche Argumentation","wissenschaftliche Debatte","wissenschaftliche Bewertung",
                 "Forschungsmethodik","wissenschaftliche Innovationen","wissenschaftliche Artikelreihe",
                 "Forschungsperspektiven","wissenschaftliche Schreibweise","wissenschaftlicher Meinungsaustausch",
                 "wissenschaftliche Abhandlung","wissenschaftliche Artikelübersicht","wissenschaftliche Zusammenfassungen",
                 "wissenschaftliche Rezension","wissenschaftliche Exzerpte","wissenschaftliche Untersuchungsergebnisse",
                 "wissenschaftliche Zitationen","Forschungsliteratur","wissenschaftliche Vorträge",
                 "wissenschaftliche Ressourcen","Forschungsmaterial","wissenschaftliche Autoren",
                 "wissenschaftliche Veröffentlichungsmöglichkeiten","wissenschaftliche Studien",
                 "wissenschaftliche Erkenntnisse","wissenschaftliche Fachartikel","wissenschaftlicher Text",
                 "wissenschaftliche Theorie","Forschungsberichte","wissenschaftliche Studienreihe",
                 "wissenschaftliche Wissensbasis","Forschungsmagazin","wissenschaftliche Erklärungen",
                 "wissenschaftliche Kritiken","wissenschaftliche Einblicke","Forschungsbuch",
                 "wissenschaftliche Artikelserie","Forschungsbeiträge","wissenschaftliche Untersuchungsreihe",
                 "wissenschaftliche Referenzen","wissenschaftliche Schriftenreihe","wissenschaftlicher Diskurs",
                 "wissenschaftliche Forschungsergebnisse","wissenschaftliche Analysen","wissenschaftliche Entwicklungen",
                 "wissenschaftliche Fortschrittsberichte","wissenschaftliche Diskussionsrunden",
                 "wissenschaftliche Innovationen","wissenschaftliche Kritik","wissenschaftliche Herausforderungen",
                 "Forschungsprojekte","wissenschaftliche Fachbereiche","wissenschaftliche Themenschwerpunkte",
                 "wissenschaftliche Diskussionen","Forschungsthemen","wissenschaftliche Literaturrecherche",
                 "wissenschaftliche Studienergebnisse","Forschungsdokumente","wissenschaftliche Artikelübersicht",
                 "wissenschaftliche Zitationsstile","Forschungsinstitute","wissenschaftliche Beiträge",
                 "wissenschaftliche Entwicklungen","wissenschaftliche Literaturübersicht","wissenschaftliche Diskussion",
                 "wissenschaftliche Diskussionsrunde","wissenschaftliche Gemeinschaft","wissenschaftlicher Austausch",
                 "wissenschaftliche Beiträge","Forschungsforschung","wissenschaftlicher Dialog",
                 "wissenschaftliche Literaturkritik","wissenschaftlicher Austausch","wissenschaftliche Innovationen",
                 "wissenschaftliche Veröffentlichungspraktiken","wissenschaftliche Verlagsarbeit","wissenschaftliche Recherche",
                 "wissenschaftliche Schreibweise","wissenschaftliche Analysen","wissenschaftliche Fachliteratur",
                 "Forschungsthemen","wissenschaftliche Perspektiven","wissenschaftliche Artikelübersicht",
                 "wissenschaftliche Zusammenfassungen","wissenschaftliche Rezension","wissenschaftliche Exzerpte",
                 "wissenschaftliche Untersuchungsergebnisse","wissenschaftliche Zitationen","Forschungsliteratur",
                 "wissenschaftliche Vorträge","wissenschaftliche Ressourcen","Forschungsmaterial",
                 "wissenschaftliche Autoren","wissenschaftliche Veröffentlichungsmöglichkeiten","wissenschaftliche Studien",
                 "wissenschaftliche Erkenntnisse","wissenschaftliche Fachartikel","wissenschaftlicher Text",
                 "wissenschaftliche Theorie","Forschungsberichte","wissenschaftliche Studienreihe",
                 "wissenschaftliche Wissensbasis","Forschungsmagazin","wissenschaftliche Erklärungen",
                 "wissenschaftliche Kritiken","wissenschaftliche Einblicke","Forschungsbuch",
                 "wissenschaftliche Artikelserie","Forschungsbeiträge","wissenschaftliche Untersuchungsreihe",
                 "wissenschaftliche Referenzen","wissenschaftliche Schriftenreihe","wissenschaftlicher Diskurs",
                 "wissenschaftliche Forschungsergebnisse","wissenschaftliche Analysen","wissenschaftliche Entwicklungen",
                 "wissenschaftliche Fortschrittsberichte","wissenschaftliche Diskussionsrunden",
                 "wissenschaftliche Innovationen","wissenschaftliche Kritik","wissenschaftliche Herausforderungen",
                 "Forschungsprojekte","wissenschaftliche Fachbereiche","wissenschaftliche Themenschwerpunkte",
                 "wissenschaftliche Diskussionen","Forschungsthemen","wissenschaftliche Literaturrecherche",
                 "wissenschaftliche Studienergebnisse","Forschungsdokumente","wissenschaftliche Artikelübersicht",
                 "wissenschaftliche Zitationsstile","Forschungsinstitute","research paper","research study",
                 "academic paper","scientific literature",
                       "scientific journal","peer-reviewed article","scientific research",
                       "scholarly article","research publication","research findings",
                       "scientific discourse","research analysis","research developments",
                       "scientific progress","research discussion","scientific insights",
                       "research review","research contributions","research series","knowledge base",
                       "research magazine","research explanations","literature review","research institute",
                       "research perspectives","research overview","research challenges","research projects",
                       "academic research","research themes","literature search","study results",
                       "research documents","article overview","citation styles","research institutes",
                       "scientific findings","research abstract","research methodology",
                       "research synthesis","research framework","scientific inquiry","academic inquiry",
                       "research exploration","research outcomes","research methodologies",
                       "research investigations","academic exploration","research perspectives",
                       "research synthesis","research advances","academic contributions","research outcomes",
                       "academic discourse","research discoveries","research breakthroughs",
                       "research insights","research exploration","academic analysis","research perspectives",
                       "scientific breakthroughs","academic insights","research investigations",
                       "academic literature","research surveys","academic research papers",
                       "scientific papers","academic discussions","research debates","academic contributions",
                       "research advancements","academic publications","research reports",
                       "scientific contributions","research discoveries","research conclusions",
                       "academic discussions","scientific debates","research implications",
                       "scientific advancements","research perspectives","academic reviews",
                       "scientific reviews","research summaries","academic summaries","research commentary",
                       "scientific commentary","academic critiques","scientific critiques","research summaries",
                       "academic perspectives","scientific perspectives","research commentaries",
                       "academic commentaries","research examinations","academic examinations",
                       "scientific examinations","research critiques","scientific critiques",
                       "academic insights","research observations","academic observations",
                       "scientific observations","research summaries","academic summaries",
                       "scientific summaries","research commentaries","academic commentaries",
                       "scientific commentaries","research examinations","academic examinations",
                       "scientific examinations","research critiques","scientific critiques",
                       "academic insights","research observations","academic observations",
                       "scientific observations","research summaries","academic summaries",
                       "scientific summaries","research commentaries","academic commentaries",
                       "scientific commentaries","research examinations","academic examinations",
                       "scientific examinations","research critiques","scientific critiques",
                       "academic insights","research observations","academic observations",
                       "scientific observations"]))

Reports_initial = list(set(["released a report","report suggests","report","bericht","survey","umfrage","poll"
           ] + ["released a report","report suggests","report","bericht","survey","umfrage","poll",
               "research report","white paper","policy report","technical report","annual report",
               "market report","economic report","industry report","government report","scientific report",
               "business report","financial report","environmental report","health report",
               "education report","technology report","assessment report","risk report","evaluation report",
               "progress report","status report","strategic report","investment report","summary report",
               "performance report","analysis report","market research report","company report",
               "project report","case study report","trend report","impact report","global report",
               "regional report","national report","international report","annual survey","public opinion poll",
               "customer satisfaction survey","industry analysis report","market trends report",
               "sustainability report","corporate social responsibility report","health and safety report",
               "quality assurance report","compliance report","risk assessment report",
               "financial performance report","budget report","forecast report","research findings report",
               "policy analysis report","technical documentation report","strategic planning report",
               "investment analysis report","case study analysis report","environmental impact report",
               "educational assessment report","technology assessment report","economic outlook report",
               "project evaluation report","program evaluation report","regulatory compliance report",
               "progress assessment report","status update report","impact assessment report",
               "business analysis report","market analysis report","industry forecast report",
               "governmental policy report","scientific research report","business performance report",
               "financial analysis report","environmental assessment report","health impact report",
               "education outcome report","technology trends report","risk management report",
               "evaluation and assessment report","strategic development report","investment strategy report",
               "performance analysis report","market research findings report","company performance report",
               "project status report","case study findings report","trend analysis report",
               "impact assessment report","global economic report","regional development report",
               "national security report","international relations report","annual progress report",
               "public health report","customer feedback report","industry outlook report",
               "market growth report","sustainability impact report","corporate responsibility report",
               "safety and compliance report","quality assurance assessment report",
               "risk mitigation report","financial planning report","budgetary analysis report",
               "forecasting trends report","research results report","policy recommendations report",
               "technical specifications report","strategic initiatives report","investment opportunities report",
               "summary and analysis report","performance metrics report","market trends analysis report",
               "company overview report","project status update report","case study analysis findings report",
               "trend impact analysis report","global market trends report","regional economic outlook report",
               "national development report","international trade report","annual performance report",
               "public opinion analysis report","customer satisfaction analysis report",
               "industry growth forecast report","sustainability metrics report",
               "corporate responsibility impact report","health and safety compliance report",
               "quality assurance performance report","risk assessment and management report",
               "financial health and performance report","budgetary planning report",
               "forecasting and analysis report","research findings and analysis report",
               "policy and strategy report","technical documentation and specifications report",
               "strategic planning and development report","investment analysis and opportunities report",
               "summary and performance analysis report","market trends and growth analysis report",
               "company performance overview report","project status and outcomes report",
               "case study analysis and findings report","trend impact analysis and projections report",
               "global market trends and insights report","regional economic outlook and development report",
               "national security and policy report","international relations and trade report",
               "annual progress and achievements report","public health and well-being report",
               "customer feedback and satisfaction report","industry outlook and predictions report",
               "market growth and expansion report","sustainability impact and initiatives report",
               "corporate responsibility and social impact report","safety and compliance performance report",
               "quality assurance and standards compliance report","risk mitigation and management report",
               "financial planning and performance report","budgetary analysis and financial outlook report",
               "forecasting trends and economic analysis report","research results and insights report",
               "policy recommendations and strategic planning report","technical specifications and documentation report",
               "strategic initiatives and development report","investment opportunities and analysis report",
               "summary and analysis of performance report","performance metrics and market trends report",
               "company overview and strategic position report","project status and outcomes update report",
               "bericht veröffentlicht","bericht schlägt vor","bericht","umfrage","umfrage","umfrage",
               "forschungsbericht","weißbuch","politikbericht","technischer bericht","jahresbericht",
               "marktbericht","wirtschaftsbericht","branchenbericht","regierungsbericht","wissenschaftlicher bericht",
               "geschäftsbericht","finanzbericht","umweltbericht","gesundheitsbericht","bildungsbericht",
               "technologiebericht","bewertungsbericht","risikobericht","evaluationsbericht",
               "fortschrittsbericht","statusbericht","strategiebericht","investitionsbericht","zusammenfassungsbericht",
               "leistungsbericht","analysenbericht","marktuntersuchungsbericht","firmenbericht",
               "projektbericht","fallstudienbericht","trendbericht","auswirkungsbericht","weltbericht",
               "regionenbericht","nationaler bericht","internationaler bericht","jahresumfrage","öffentlichkeitsumfrage",
               "kundenzufriedenheitsumfrage","branchenanalysebericht","marktrendsbericht",
               "nachhaltigkeitsbericht","bericht zur unternehmenssozialverantwortung","gesundheits- und sicherheitsbericht",
               "qualitätssicherungsbericht","compliance-bericht","risikobewertungsbericht",
               "finanzbericht","budgetbericht","prognosebericht","forschungsergebnisbericht",
               "politikanalysebericht","technischer dokumentationsbericht","strategiebericht",
               "investitionsanalysebericht","fallstudienanalysebericht","umweltauswirkungsbericht",
               "bildungsbeurteilungsbericht","technologiebeurteilungsbericht","wirtschaftsausblickbericht",
               "projektevaluierungsbericht","programmevaluierungsbericht","regulatorischer compliance-bericht",
               "fortschrittsbewertungsbericht","statusaktualisierungsbericht","auswirkungsbewertungsbericht",
               "geschäftsanalysebericht","marktanalysebericht","branchenprognosebericht","staatspolitischer bericht",
               "wissenschaftlicher forschungsbericht","geschäftsleistungsbericht","finanzanalysebericht",
               "umweltauswirkungsbericht","gesundheitsbericht","bildungsbericht","technologietrendsbericht",
               "risikomanagementbericht","bewertungs- und bewertungsbericht","strategischer entwicklungsbericht",
               "investitionsstrategiebericht","leistungsanalysebericht","marktuntersuchungsergebnissebericht",
               "firmenleistungsbericht","projektstatusbericht","fallstudienanalyseergebnisbericht",
               "trendanalysebericht","auswirkungsbewertungs- und projizierungsbericht",
               "weltweiter markttrendsbericht","regionale wirtschaftsaussichtenbericht",
               "nationaler entwicklungsbericht","internationale handelsbericht","jährlicher fortschrittsbericht",
               "gesundheitsbericht","kundenfeedbackbericht","branchenausblickbericht","markt- und expansionsbericht",
               "nachhaltigkeitswirkungsbericht","bericht zur unternehmensverantwortung","gesundheits- und sicherheitsleistungsbericht",
               "qualitätssicherungs- und standardscompliance-bericht","risikobewertungs- und managementbericht",
               "finanzplanungs- und leistungsbericht","budgetanalyse- und finanzieller ausblicksbericht",
               "trend- und wirtschaftsanalysebericht","forschungsergebnis- und einblickebericht",
               "politikempfehlungs- und strategiebericht","technische spezifikations- und dokumentationsbericht",
               "strategieinitiativen- und entwicklungsbericht","investitionsmöglichkeiten- und analysebericht",
               "zusammenfassungs- und leistungsanalysebericht","markttrends- und wachstumsanalysebericht",
               "firmenübersichts- und strategiepositionsbericht","projektstatus- und ergebnisbericht"]))

Official_statements_initial = list(set(["letter","statement","speech","opinion","kapitalmarktinformation","stellungnahme",
                      "ansprache","kundmachung","Bekanntmachung","offizielle Mitteilung","Verkundbarung",
                      "Verlautbarung","eröffnungsrede","bundestagsrede"
                      ] + ["letter","statement","speech","opinion","kapitalmarktinformation","stellungnahme",
                      "ansprache","kundmachung","Bekanntmachung","offizielle Mitteilung","Verkundbarung",
                      "Verlautbarung","eröffnungsrede","bundestagsrede",
                      "brief","declaration","address","view","capital market information","expression of opinion",
                      "speech","announcement","public notice","official communication","proclamation",
                      "pronouncement","opening address","parliamentary speech",
                      "missive","pronunciamento","manifesto","communication","communiqué","utterance","broadcast",
                      "discourse","lecture","talk","missive","dispatch","statement of beliefs","formal declaration",
                      "declaration of intent","press release","media release","official briefing","policy statement",
                      "position paper","briefing","information dissemination","press statement","state paper",
                      "edict","decree","ukase","advice","communique","missive","directive","announcement",
                      "public declaration","verbalization","verbiage","talk","presentation","oratory","sermon",
                      "harangue","homily","oration","spiel","symposium","panel discussion","forum","congress",
                      "colloquium","seminar","discussion","forum","assembly","gathering","meeting","conference",
                      "conclave","summit","roundtable","dialogue","debate","conversation","exchange of views",
                      "consultation","deliberation","parley","treaty negotiation","diplomatic statement",
                      "official report","document","white paper","policy briefing","policy document","memorandum",
                      "press briefing","broadcasting","declaration of principles","public speech","formal address",
                      "public proclamation","communal statement","governmental communication",
                      "schreiben","aussage","rede","meinung","kapitalmarktinformation","stellungnahme",
                      "ansprache","kundmachung","bekanntmachung","offizielle mitteilung","verkundbarung",
                      "verlautbarung","eröffnungsrede","bundestagsrede",
                      "brief","erklärung","adresse","ansicht","kapitalmarktinformation","äußerung",
                      "rede","ankündigung","öffentliche bekanntgabe","amtliche mitteilung","proklamation",
                      "verkündung","öffentliche ansprache","parlamentsrede","schreiben","erklärung",
                      "adresse","ansicht","kapitalmarktinformation","äußerung","rede","ankündigung",
                      "öffentliche bekanntgabe","amtliche mitteilung","proklamation","verkündung",
                      "öffentliche ansprache","parlamentsrede","schriftstück","bekanntgabe","manifest",
                      "kommunikation","kommuniqué","äußerung","rundfunk","diskurs","vorlesung","gespräch",
                      "schriftstück","sendung","glaubensbekenntnis","formelle erklärung","absichtserklärung",
                      "pressemitteilung","presseerklärung","amtliche unterrichtung","politische erklärung",
                      "standpunktspapier","einweisung","informationverbreitung","presseerklärung",
                      "staatspapier","erlass","dekret","ukas","ratschlag","kommuniqué","schriftstück",
                      "direktive","ankündigung","öffentliche erklärung","verbalisierung","wortwahl",
                      "sprechweise","vortrag","präsentation","rede","predigt","lehrstunde","ansprache",
                      "harangue","predigt","rede","vortrag","symposium","podiumsdiskussion","forum",
                      "kongress","kollegium","seminar","diskussion","forum","versammlung","zusammenkunft",
                      "meeting","konferenz","konklave","gipfel","rundtischgespräch","dialog","debatte",
                      "gespräch","austausch von ansichten","konsultation","beratung","gesprächsrunde",
                      "verhandlung","diplomatische erklärung","amtlicher bericht","dokument","weißbuch",
                      "politische information","memorandum","pressekonferenz","rundfunk","prinzipienerklärung",
                      "öffentliche rede","formelle ansprache","öffentliche bekanntmachung",
                      "gemeinsame erklärung","staatliche kommunikation"]))

Guidelines_initial = list(set(["guideline","rundschreiben","circular","faq","q&a","questions & answers","questions and answers",
             "leitfaden","anleitung","hinweis","handlungsanweisung","norm","häufig gestellte fragen",
             "Hilfestellung","Anleitung","leitlinie"
             ] + ["guideline","rundschreiben","circular","faq","q&a","questions & answers","questions and answers",
             "leitfaden","anleitung","hinweis","handlungsanweisung","norm","häufig gestellte fragen",
             "Hilfestellung","Anleitung","leitlinie",
             "instruction","directive","manual","frequently asked questions","guide","reference","help",
             "directions","standard","norm","protocol","procedure","guidance note","handbook","set of rules",
             "policies","procedures","operating procedures","advice","tips","how-to","user guide","manual",
             "reference book","handbook","guidebook","reference manual","code of conduct","conduct guidelines",
             "instructions","operating instructions","procedural guidelines","frequently asked questions",
             "Q&A session","question and answer session","question and answer format","response guide",
             "guiding principles","policy","set of instructions","rules and regulations",
             "operating principles","standard operating procedure","operating manual",
             "set of guidelines","guiding document","guidance","directions","step-by-step instructions",
             "guidance manual","regulatory guidelines","code of practice","best practices",
             "guide for action","reference guide","instruction manual","rulebook",
             "frequently asked questions and answers","user manual",
             "protocol","compendium","suggestion","counsel","recommendation","proposition",
             "advisory","pointer","guidepost","marker","signpost","waymark","lead","pathfinder",
             "counseling","counseling session","counselor's guide","roadmap","policy guidelines",
             "methodology guide","standardization","informational guide","navigation","orientation",
             "road guide","informational material","directory","aid","prompt","steer","clue",
             "indicator","cue","signal","notation","regulation","rule","statute","prescription",
             "decree","ordinance","law","act","enactment","legislation","constitution",
             "code","canon","formula","principle","precept","maxim","law of conduct",
             "ethics code","behavioral guidelines","professional guidelines","protocol",
             "best practices guide","norms and standards","manual of procedures",
             "instructional guidebook","operational manual",
             "richtlinie","rundschreiben","faq","fragen & antworten","fragen und antworten",
             "leitfaden","anleitung","hinweis","handlungsanweisung","norm","häufig gestellte fragen",
             "hilfestellung","anleitung","leitlinie",
             "instruktion","direktive","handbuch","häufig gestellte fragen","anleitung","referenz","hilfe",
             "anweisungen","standard","norm","protokoll","verfahren","hinweis","handbuch","regelwerk",
             "richtlinien","verfahren","betriebsanweisungen","rat","tipps","wie-geht's","benutzerhandbuch",
             "anleitung","referenzbuch","handbuch","ratgeber","referenzhandbuch","verhaltenskodex",
             "verhaltensrichtlinien","anweisungen","betriebsanweisungen","prozedurale richtlinien",
             "häufig gestellte fragen","frage- und antwortrunde","frage- und antwortformat","antwortführer",
             "leitprinzipien","richtlinie","anweisungssatz","regeln und vorschriften",
             "betriebsprinzipien","standardbetriebsverfahren","betriebsanleitung",
             "richtliniensatz","leitfaden","anweisungen","schritt-für-schritt-anleitungen",
             "anleitungshandbuch","regulatorische richtlinien","praxisrichtlinien",
             "handlungsanleitung","referenzleitfaden","anleitungshandbuch","regelbuch",
             "häufig gestellte fragen und antworten","benutzerhandbuch",
             "protokoll","kompendium","vorschlag","beratung","empfehlung","vorschlag",
             "beratung","beratungssitzung","beraterleitfaden","landkarte","richtlinien",
             "methodenleitfaden","standardisierung","informationsleitfaden","navigation","orientierung",
             "wegweiser","informationsmaterial","verzeichnis","hilfe","hinweis","führung","tipp",
             "steuerung","hinweis","indikator","signal","notation","verordnung","regel","statut","verschreibung",
             "dekret","verordnung","gesetz","akt","erlass","gesetzgebung","verfassung","kodex",
             "formel","prinzip","prinzip","gesetz des verhaltens","ethikkodex","verhaltensrichtlinien",
             "professionelle richtlinien","protokoll",
             "richtlinien und standards","verfahrensanleitung","anleitungshandbuch"]))

Press_releases_initial = list(set(["press release","newsletter","pressemitteilung","pressemeldung","pressebericht",
                 "press announcement","press statement","media release","news release","press communiqué"
                 ] + ["press release","newsletter","pressemitteilung","pressemeldung","pressebericht",
                 "press announcement","press statement","media release","news release","press communiqué",
                 "public announcement","information bulletin","news bulletin","communication to the media",
                 "press report","media statement","briefing","newsflash","media advisory","news update",
                 "news flash","official statement to the press","press briefing","media briefing",
                 "press information","press notice","press coverage","press exposition","press publication",
                 "press release article","press coverage report","news article","media coverage",
                 "media exposure","media notice","news story","news report","news broadcast","media broadcast",
                 "press transmission","news transmission","media transmission","media release article",
                 "public relations message","publicity release","media bulletin","news alert",
                 "press release statement","press release note","press reportage","media reportage",
                 "press dossier","media dossier","press folder","news folder","media folder",
                 "press file","news file","media file","press kit","news kit","media kit",
                 "press pack","news pack","media pack","press publication","media publication",
                 "press publicity","media publicity","press statement article","news statement article",
                 "media statement article","press communication","media communication","press notice report",
                 "media notice report","press coverage update","media coverage update","press article update",
                 "media article update","press story update","media story update","press briefing article",
                 "media briefing article","press exposition article","media exposition article",
                 "press release coverage","media release coverage","press release exposition",
                 "media release exposition","press release publication","media release publication",
                 "press release publicity","media release publicity","press release reportage",
                 "media release reportage","press release dossier","media release dossier",
                 "press release folder","media release folder","press release file","media release file",
                 "press release kit","media release kit","press release pack","media release pack",
                 "press release article update","media release article update","press release coverage update",
                 "media release coverage update","press release exposition update","media release exposition update",
                 "press release publication update","media release publication update",
                 "press release publicity update","media release publicity update","press release reportage update",
                 "media release reportage update","press release dossier update","media release dossier update",
                 "press release folder update","media release folder update","press release file update",
                 "media release file update","press release kit update","media release kit update",
                 "press release pack update","media release pack update",
                 "pressemitteilung","newsletter","pressemitteilung","pressebericht",
                 "presseankündigung","presseerklärung","medienmitteilung","nachrichtenmitteilung",
                 "pressecommuniqué","öffentliche ankündigung","informationsbulletin","nachrichtenbulletin",
                 "kommunikation an die medien","pressebericht","medienmitteilung","briefing",
                 "newsflash","medienberatung","nachrichtenaktualisierung","nachrichtenblitz",
                 "offizielle erklärung an die presse","pressebriefing","medienbriefing",
                 "presseinformation","pressemitteilung","pressebericht","presseexposition",
                 "presseveröffentlichung","presseartikel","pressebericht","nachrichtenartikel",
                 "medienberichterstattung","medienpräsenz","medienhinweis","nachrichtengeschichte",
                 "nachrichtenbericht","nachrichtenübertragung","medienübertragung","presseartikel",
                 "öffentliche relations-nachricht","öffentliche pressemitteilung","medienbulletin",
                 "nachrichtenalarm","pressemitteilungserklärung","pressemitteilungshinweis",
                 "presseberichterstattung","medienberichterstattung","pressemappe","medienmappe",
                 "presseordner","nachrichtenordner","medienordner","presseakte","nachrichtenakte",
                 "medienakte","pressekit","nachrichtenkit","mediakit","pressepaket","nachrichtenpaket",
                 "mediapaket","presseveröffentlichung","medienveröffentlichung","pressewerbung",
                 "medienwerbung","presseartikel","nachrichtenartikel","medienartikel",
                 "pressekommunikation","medienkommunikation","pressehinweisbericht",
                 "medienhinweisbericht","presseberichterstattungaktualisierung",
                 "medienberichterstattungaktualisierung","presseartikelaktualisierung",
                 "medienartikelaktualisierung","pressegeschichteaktualisierung",
                 "medienberichterstattungaktualisierung","pressemitteilungsdossier",
                 "medienmitteilungsdossier","presseordneraktualisierung",
                 "nachrichtenordneraktualisierung","medienordneraktualisierung",
                 "presseakteaktualisierung","nachrichtenakteaktualisierung",
                 "medienakteaktualisierung","pressekitaktualisierung","nachrichtenkitaktualisierung",
                 "mediakitaktualisierung","pressepaketaktualisierung","nachrichtenpaketaktualisierung",
                 "mediapaketaktualisierung"]))

Personnel_changes_initial = list(set(["Neuer Chef","Neuer Head of","übernimmt Leitung","zieht in Vorstand",
                    "zieht in Aufsichtsrat","mit neuem Bereichs","leitet Generationenwechsel",
                    "stockt Personal","ernennt C","ins Führungsteam","holt renommierte Manager",
                    "besetzt Spitzenposition","Neuer Chief","hiring","job candidate","indeed.com",
                    "new job","job role","trainee","talent scout","talent acquisition","recruitment",
                    "head hunter","executive search","new staff","Professionals search","job search",
                    "talent identification","job description","interviewee","job interview",
                    "job application","employment contract","recruitment process","external recruitment",
                    "candidate attraction","job profile","candidate profile","candidate skills",
                    "required skills","Recruiting","Job","Arbeitsplatzrolle","Praktikantin",
                    "Talentsucher","Talentakquise","Rekrutierung","Headhunter","executive search",
                    "neue Mitarbeiter","recruiter","bewerbermesse","jobmesse","Stellenbeschreibung",
                    "Dienstvertrag","Arbeitsvertrag","Rekrutierungsprozess","externe Rekrutierung",
                    "Kandidatengewinnung","Stellenangebot","Stellenanzeige","Stellenausschreibung",
                    "Job Vakanz","Job Posting","Job Postings","(mwd)","(mfd)","(fmd)","Praktikant:in",
                    "Assitent:in","(mwdivers)"
                    ] + ["Neuer Chef","Neuer Head of","übernimmt Leitung","zieht in Vorstand",
                    "zieht in Aufsichtsrat","mit neuem Bereichs","leitet Generationenwechsel",
                    "stockt Personal","ernennt C","ins Führungsteam","holt renommierte Manager",
                    "besetzt Spitzenposition","Neuer Chief","hiring","job candidate","indeed.com",
                    "new job","job role","trainee","talent scout","talent acquisition","recruitment",
                    "head hunter","executive search","new staff","Professionals search","job search",
                    "talent identification","job description","interviewee","job interview",
                    "job application","employment contract","recruitment process","external recruitment",
                    "candidate attraction","job profile","candidate profile","candidate skills",
                    "required skills","Recruiting","Job","Arbeitsplatzrolle","Praktikantin",
                    "Talentsucher","Talentakquise","Rekrutierung","Headhunter","executive search",
                    "neue Mitarbeiter","recruiter","bewerbermesse","jobmesse","Stellenbeschreibung",
                    "Dienstvertrag","Arbeitsvertrag","Rekrutierungsprozess","externe Rekrutierung",
                    "Kandidatengewinnung","Stellenangebot","Stellenanzeige","Stellenausschreibung",
                    "Job Vakanz","Job Posting","Job Postings","(mwd)","(mfd)","(fmd)","Praktikant:in",
                    "Assitent:in","(mwdivers)",
                    "personelle Veränderungen","neue Position","Veränderung im Management",
                    "Wechsel in Führungsebene","Wechsel im Vorstand","Wechsel im Aufsichtsrat",
                    "mit neuem Verantwortungsbereich","Generationswechsel","Personalaufstockung",
                    "Ernennung von C","Zugang zum Führungsteam","Anstellung renommierter Manager",
                    "Besetzung von Schlüsselpositionen","Neuer Vorstandsvorsitzender",
                    "Anwerbung","Bewerber","indeed.com","neue Stelle","Stellenrolle","Trainee",
                    "Talentsucher","Talentakquise","Personalbeschaffung","Headhunter",
                    "executive search","neues Personal","Professionals search","Jobsuche",
                    "Talentidentifikation","Stellenbeschreibung","Bewerbergespräch","Bewerbungsgespräch",
                    "Bewerbung","Arbeitsvertrag","Rekrutierungsprozess","externe Rekrutierung",
                    "Kandidatenanziehung","Jobprofil","Bewerberprofil","Bewerberfähigkeiten",
                    "erforderliche Fähigkeiten","Recruiting","Job","Arbeitsplatzrolle","Praktikantin",
                    "Talentsucher","Talentakquise","Rekrutierung","Headhunter","executive search",
                    "neue Mitarbeiter","Recruiter","Bewerbermesse","Jobmesse","Stellenbeschreibung",
                    "Dienstvertrag","Arbeitsvertrag","Rekrutierungsprozess","externe Rekrutierung",
                    "Kandidatengewinnung","Stellenangebot","Stellenanzeige","Stellenausschreibung",
                    "Job Vakanz","Job Posting","Job Postings","(mwd)","(mfd)","(fmd)","Praktikant:in",
                    "Assitent:in","(mwdivers)"]))

Market_Analysis_initial = list(set(["Aktien Europa","behält die Bewertung","Kurserholung","Stock:","'halten'","'kaufen'",
                  "Märkte am Morgen","DAX","Dow Jones","chartanalyse","gross profit margin","ISIN",
                  "stock rating","'verkaufen'","'hold'","'buy'","'sell'","'moderate buy'","price prediction",
                  "price remains above","price remains below","best stocks","raised its price","Price Target",
                  "Release of capital market information","Analysts have given","'Buy'","'Moderate Buy'",
                  "'Sell'","'Hold'","reiteratives its rating on","increase in short interest","buy rating",
                  "sell rating","hold rating","aktienrückkauf","kurssturz","drückt Kurse","Aktienkurs",
                  "fall in the shares","worth of shares","Milliardenplatzierung","roundupaktien","estimatekurse",
                  "realtime kurse","aktie angepasst","Aktie:","aktie stabil","aktie volatil","der kurs der aktie",
                  "aktie news","shareholder","aktie dämmt","der aktionaer","Aktie News","Kursplus","Kursminus",
                  "Kurssprung","der aktionär","'buy'","'sell'","boerse.de","aktiencheck","Dividendensaison",
                  "DAXAktien","DAX-Aktien","share price","Aktie bü0t","Aktie gewinnt","stock loss","stock win",
                  "kursziel","prognostizierten die Analysten","kursgewinn","aktien im sinkflug","aktie im",
                  "Preisrally","Price Update","Bearish Signal","Bullish Signal","bear market","bull market",
                  "bear signal","bull signal","Price Prediction:","losses below $","losses below \u20AC",
                  "recover to $","recover to \u20AC","consolidates above $","resistance at $","reclaims $",
                  "to break $","drop to $","drop to \u20AC","price correction","Preiskorrektur","bounces above $",
                  "bounces above \u20AC","rejection at $","rejection at \u20AC","pauses above $","pauses below $",
                  "revisit $","slumps above $"
                  ] + ["Aktien Europa","behält die Bewertung","Kurserholung","Stock:","'halten'","'kaufen'",
                  "Märkte am Morgen","DAX","Dow Jones","chartanalyse","gross profit margin","ISIN",
                  "stock rating","'verkaufen'","'hold'","'buy'","'sell'","'moderate buy'","price prediction",
                  "price remains above","price remains below","best stocks","raised its price","Price Target",
                  "Release of capital market information","Analysts have given","'Buy'","'Moderate Buy'",
                  "'Sell'","'Hold'","reiteratives its rating on","increase in short interest","buy rating",
                  "sell rating","hold rating","aktienrückkauf","kurssturz","drückt Kurse","Aktienkurs",
                  "fall in the shares","worth of shares","Milliardenplatzierung","roundupaktien","estimatekurse",
                  "realtime kurse","aktie angepasst","Aktie:","aktie stabil","aktie volatil","der kurs der aktie",
                  "aktie news","shareholder","aktie dämmt","der aktionaer","Aktie News","Kursplus","Kursminus",
                  "Kurssprung","der aktionär","'buy'","'sell'","boerse.de","aktiencheck","Dividendensaison",
                  "DAXAktien","DAX-Aktien","share price","Aktie bü0t","Aktie gewinnt","stock loss","stock win",
                  "kursziel","prognostizierten die Analysten","kursgewinn","aktien im sinkflug","aktie im",
                  "Preisrally","Price Update","Bearish Signal","Bullish Signal","bear market","bull market",
                  "bear signal","bull signal","Price Prediction:","losses below $","losses below \u20AC",
                  "recover to $","recover to \u20AC","consolidates above $","resistance at $","reclaims $",
                  "to break $","drop to $","drop to \u20AC","price correction","Preiskorrektur","bounces above $",
                  "bounces above \u20AC","rejection at $","rejection at \u20AC","pauses above $","pauses below $",
                  "revisit $","slumps above $",
                  "Marktanalyse","Aktienmarkt","Kursanalyse","Bewertung beibehalten","Kurserholung","Aktien:",
                  "'Halten'","'Kaufen'","Märkte am Morgen","DAX","Dow Jones","Chartanalyse","Bruttogewinnmarge",
                  "ISIN","Aktienbewertung","'Verkaufen'","'Halten'","'Kaufen'","'Verkaufen'","'Moderat Kaufen'",
                  "Preisprognose","Preis bleibt über","Preis bleibt unter","beste Aktien","erhöht ihren Preis",
                  "Preisziel","Veröffentlichung von Kapitalmarktinformationen","Analysten haben gegeben","'Kaufen'",
                  "'Moderat Kaufen'","'Verkaufen'","'Halten'","beharrt auf seiner Bewertung","Zunahme des Leerverkaufs",
                  "Kaufempfehlung","Verkaufsempfehlung","Halteempfehlung","Aktienrückkauf","Kurssturz",
                  "drückt die Kurse","Aktienkurs","Rückgang der Aktien","Wert der Aktien","Milliardenplatzierung",
                  "Roundup-Aktien","Schätzkurse","Echtzeitkurse","Aktien angepasst","Aktien:",
                  "Aktien stabil","Aktien volatil","Der Kurs der Aktie","Aktiennews","Aktionär",
                  "Aktien dämpfen","Der Aktionär","Aktiennews","Kursplus","Kursminus","Kurssprung",
                  "Der Aktionär","'Kaufen'","'Verkaufen'","boerse.de","Aktiencheck","Dividendensaison",
                  "DAX-Aktien","Aktienkurs","Aktie bietet","Aktie gewinnt","Aktienverlust","Aktiengewinn",
                  "Kursziel","Prognose der Analysten","Kursgewinn","Aktien im Sinkflug","Aktie im",
                  "Preisrallye","Preisupdate","Bearish-Signal","Bullish-Signal","Bärenmarkt","Bullenmarkt",
                  "Bärisches Signal","Bullishes Signal","Preisprognose","Verluste unter $","Verluste unter \u20AC",
                  "Erholung auf $","Erholung auf \u20AC","konsolidiert über $","Widerstand bei $","erobert $",
                  "um $ zu brechen","fällt auf $","fällt auf \u20AC","Preiskorrektur","Preiskorrektur",
                  "springt über $","springt über \u20AC","Ablehnung bei $","Ablehnung bei \u20AC",
                  "pausiert über $","pausiert unter $","besucht $","sinkt über $"]))

# %%
# More cleaning
rh_legal_docs = ["regulation","regulations","order","Commission Implementing Decision",
                  "act","comission decision","amendment","directive","rule","rts",
                  "technical specification","Council Framework Decision","richtlinie",
                  "verordnung","regulatory technical standards","regulatory specification",
                  "legislation","gesetz"]
Legal_documents = ['richtlinie', 'richtlinien', 'bylaw', 'resolution',
                   'resolutions', 'law', 'laws', 'legal', 'verordnung',
                   'verordnungen' 'regierungsverordnung', 'regierungsverordnungen',
                   'regulation', 'regulations', 'gerichtsetscheidung', 'gerichtsetscheidungen',
                   'jurisprudence', 'gesetzgebung', 'mandate', 'government order',
                   'legislation', 'edict', 'ordinance', 'executive order', 'warrant',
                   'rts', 'amendment', 'regulatory', 'court order', 'gesetz', 'gesetze',
                   'statute', 'statues', 'norm', 'norms', 'ruling', 'act', 'directive']

rh_warn_enf_sanc = ["Fine","accuse","fined","fines","Milliardenbusse",
                    "lawsuite","Strafe","Warnung","Sanction","Sanctions","Sanktions",
                    "schadenersatzanspruch","schadenersatzansprüche","schadenersatz verurteilt",
                    "Sanktionen","richterliche entscheidung","juristische entscheidung",
                    "gerichtliche","is not authorised to","administrative fine",
                    "disciplinary fine","unlawful use of","has not granted",
                    "launches investigation","Sanktion","Bafin investigates",
                    "has not been granted authorisation","without our authorisation",
                    "keine Erlaubnis nach dem","unerbetene Anrufe","prohibits unauthorised",
                    "unauthorised provision","unterliegt nicht der Aufsicht","withdrawal",
                    "unlicenced entity","fines","breaches","verstoß","verstöße",
                    "suspends","verstösse","Strafe","unauthorised business","ermittelt gegen",
                    "Strafmaßnahme","suspension of trading","Warning","untersagt die unerlaubt",
                    "Sanction","Enforcement","Achtung!","Vollstreckung","Sanktionsmaßnahme",
                    "Durchsetzung","warnt Anleger","Betroffene","mögliche Nachteile",
                    "verhängt Sanktion","Kundmachung","Öffentlichkeit informieren"]
Warnings_Enforcements_Sanctions = ['sanktionsmaßnahme', 'sanktionsmaßnahmen', 'Sanktion',
                                   'sanktionen', 'prozess', 'prozesse', 'strafrechlich',
                                   'strafrechtliche', 'enforcement', 'enforcements',
                                   'sanction', 'sanctions', 'warnung', 'warnungen', 'verwarnung',
                                   'verwarnungen', 'warning', 'warnings', 'strafe', 'strafen',
                                   'breach', 'breaches', 'verurteilung', 'millionenstrafe',
                                   'milliardenstrafe', 'betroffener', 'betroffene', 'durchsetzung',
                                   'fine', 'fines', 'gerichtliche', 'fined', 'richterliche', 'bafin',
                                   'investigation', 'investigations', 'ermittlungen', 'ermittelt',
                                   'ermittlung', 'verhängt', 'verhängen', 'lawsuite', 'lawsuits',
                                   'verstoß', 'verstöße', 'strafverfolgung', 'durchgesetzt',
                                   'juristisch', 'juristische', 'investigate', 'investigated',
                                   'unauthorized', 'schadenersatz', 'schadenersatzanspruch',
                                   'richterlich', 'richterliche', 'withdrawal', 'suspend',
                                   'suspends', 'suspension', 'ermittelt', 'ermittlung', 'ermitteln',
                                   'enforcement', 'enforcements', 'vollstreckung', 'vollstrecken',
                                   'durchsetzen', 'durchsetzung']

rh_sci_papers = ["issues alert","whitepaper","working paper","white paper","wissenschaftlicher artikel",
                 "wissenschaftliche publikation","studie","study","wissenschaftlicher aufsatz",
                 "essay","studie:","wissenschaftliche publikation","science paper","wissenschaftliche Abhandlung",
                 "wissenschaftliche Arbeit","publikation"]
Science_papers = ['wissenschaftlicher', 'wissenschaftliche', 'academic', 'publication',
                  'publikation', 'Fachzeitschriftartikel', 'Fachbeitrag', 'fachartikel',
                  'research', 'publications', 'Forschungspublikationen', 'studien',
                  'publikationen', 'essay', 'Forschungsmaterial', 'studie', 'Forschungsberichte',
                  'Forschungsfeld', 'Forschungsbericht', 'Forschungsarbeit', 'Forschungsmagazin',
                  'academic journal', 'science journal', 'Wissenschaftsjournal', 'scientific',
                  'studien', 'Forschungseinrichtung', 'Forschungsergebnisse', 'Studienbericht',
                  'study', "issues alert","whitepaper", "working paper","white paper",
                  'studie:', 'science paper', 'studies', 'study:', 'issues alert', 'whitepaper']

rh_reps = ["released a report","report suggests","report","bericht","survey","umfrage","poll"]
Reports = ["report","bericht","survey","umfrage","poll",'finanzbericht',
           'geschäftsbericht', 'marktbericht', 'reports', 'berichte',
           'surveys', 'nachhaltigkeitsbericht', 'umfrage', 'poll',
           'jahresbericht', 'umfragen', 'polls', 'finanzberichte',
           'geschäftsberichte', 'marktberichte', 'jahresberichte']

rh_of_statements = ["letter","statement","speech","opinion","kapitalmarktinformation","stellungnahme",
                    "ansprache","kundmachung","Bekanntmachung","offizielle Mitteilung","Verkundbarung",
                    "Verlautbarung","eröffnungsrede","bundestagsrede"]
Official_statements = ['statement', 'statements', 'staatspapier', 'staatspapiere',
                       'bekanntmachung', 'bekanntmachungen', 'capital market information',
                       'kapitalmarktinformation', 'ansprache', 'briefing', 'bekanntgabe',
                       'speech', 'letter', 'stellungnahme', 'edict', 'memorandum',
                       'announcement', 'announced', 'announcing', 'eröffnungsrede',
                       'absichtserklärung', 'oration', 'speech', 'kundmachung',
                       'offizielle', 'verkundbarung', 'verlautbarung', 'bundestagsrede']

rh_guides = ["guideline","rundschreiben","circular","faq","q&a","questions & answers","questions and answers",
             "leitfaden","anleitung","hinweis","handlungsanweisung","norm","häufig gestellte fragen",
             "Hilfestellung","Anleitung","leitlinie"]
Guidelines = ['fragen und antworten', 'fragen & antworten', 'tipps', 'faq', 'f&q',
              'q&a', 'rules', 'policies', 'questions and answers', 'leitfaden',
              'questions & answers', 'ratgeber', 'leitlinie', 'leitlinien',
              'best practise', 'best practises', 'handbook', 'handbuch', 'hinweis',
              'user manual', 'anleitung', 'anleitungen', 'user manuals', 'guideline',
              'guidelines', 'guidance', 'rat', 'rulebook', 'rule', 'instructions',
              'instruction', 'regelwerk', 'tips', 'guide', 'guides', 'richtlinie',
              'richtlinien', 'norm', 'rundschreiben', 'circular', 'handlungsanweisung',
              'hinweis', 'hilfestellung', 'f & q', 'f a q', 'q & a', 'reference',
              'häufig gestellte fragen']

rh_ress_rels = ["press release","newsletter","pressemitteilung","pressemeldung","pressebericht",
                "press announcement","press statement","media release","news release","press communiqué"]
Press_releases = ['press', 'news', 'presse', 'pressebericht', 'presseberichte',
                  'briefing', 'medienmitteilung', 'medien', 'medienmitteilungen',
                  'media', 'presseinformation', 'presseinformationen', 'newsletter',
                  'newsflash', 'pressemitteilung', 'pressemitteilungen', 'pressemeldung',
                  'pressemeldungen', 'pressebericht', 'presseberichte']

rh_pers_changes = ["Neuer Chef","Neuer Head of","übernimmt Leitung","zieht in Vorstand",
                   "zieht in Aufsichtsrat","mit neuem Bereichs","leitet Generationenwechsel",
                   "stockt Personal","ernennt C","ins Führungsteam","holt renommierte Manager",
                   "besetzt Spitzenposition","Neuer Chief","hiring","job candidate","indeed.com",
                   "new job","job role","trainee","talent scout","talent acquisition","recruitment",
                   "head hunter","executive search","new staff","Professionals search","job search",
                   "talent identification","job description","interviewee","job interview",
                   "job application","employment contract","recruitment process","external recruitment",
                   "candidate attraction","job profile","candidate profile","candidate skills",
                   "required skills","Recruiting","Job","Arbeitsplatzrolle","Praktikantin",
                   "Talentsucher","Talentakquise","Rekrutierung","Headhunter","executive search",
                   "neue Mitarbeiter","recruiter","bewerbermesse","jobmesse","Stellenbeschreibung",
                   "Dienstvertrag","Arbeitsvertrag","Rekrutierungsprozess","externe Rekrutierung",
                   "Kandidatengewinnung","Stellenangebot","Stellenanzeige","Stellenausschreibung",
                   "Job Vakanz","Job Posting","Job Postings","(mwd)","(mfd)","(fmd)","Praktikant:in",
                   "Assitent:in","(mwdivers)"]
Personnel_changes = ['neue stelle', 'neuer chef', 'recruiter', 'rekrutierung',
                     'neuer chief', 'job', 'jobs', 'trainee', 'generationswechsel',
                     'executive search', 'stellenausschreibung', 'stellenanzeige',
                     'jobsuche', 'recruiter', 'mwd', '(mwd)', 'm/w/d', 'fmd',
                     '(fmd)', 'f/m/d', 'neue position', 'mitarbeiter', 'mitarbeiterin',
                     'mitarbeiter*innen', 'recruitment', 'recruiting', 'personal',
                     'personnel', 'bewerbung', 'headhunter', 'neuer vorstandsvorsitzender',
                     'neue chefin', 'neue chief', 'neue vorstandsvorsitzende', 'jobprofil',
                     'stellenangebot', 'staff', 'staffing', 'interviewee', 'übernimmt leitung',
                     'neuer head of', 'neue head of', 'zieht in aufsichtsrat', 'bewerber',
                     'applicant', 'zieht in vorstand', 'bewerbungsgespräch', 'bewerberin',
                     'praktikant', 'praktikanting', 'talent', 'c-level', 'c level', 'hiring',
                     'mwdivers', '(mwdivers)', 'ins führungsteam', 'personelle veränderungen',
                     'lay offs', 'kündigung', 'kündigungen', 'laid off', 'emplyment']

rh_mar_analysis = ["Aktien Europa","behält die Bewertung","Kurserholung","Stock:","'halten'","'kaufen'",
                  "Märkte am Morgen","DAX","Dow Jones","chartanalyse","gross profit margin","ISIN",
                  "stock rating","'verkaufen'","'hold'","'buy'","'sell'","'moderate buy'","price prediction",
                  "price remains above","price remains below","best stocks","raised its price","Price Target",
                  "Release of capital market information","Analysts have given","'Buy'","'Moderate Buy'",
                  "'Sell'","'Hold'","reiteratives its rating on","increase in short interest","buy rating",
                  "sell rating","hold rating","aktienrückkauf","kurssturz","drückt Kurse","Aktienkurs",
                  "fall in the shares","worth of shares","Milliardenplatzierung","roundupaktien","estimatekurse",
                  "realtime kurse","aktie angepasst","Aktie:","aktie stabil","aktie volatil","der kurs der aktie",
                  "aktie news","shareholder","aktie dämmt","der aktionaer","Aktie News","Kursplus","Kursminus",
                  "Kurssprung","der aktionär","'buy'","'sell'","boerse.de","aktiencheck","Dividendensaison",
                  "DAXAktien","DAX-Aktien","share price","Aktie bü0t","Aktie gewinnt","stock loss","stock win",
                  "kursziel","prognostizierten die Analysten","kursgewinn","aktien im sinkflug","aktie im",
                  "Preisrally","Price Update","Bearish Signal","Bullish Signal","bear market","bull market",
                  "bear signal","bull signal","Price Prediction:","losses below $","losses below \u20AC",
                  "recover to $","recover to \u20AC","consolidates above $","resistance at $","reclaims $",
                  "to break $","drop to $","drop to \u20AC","price correction","Preiskorrektur","bounces above $",
                  "bounces above \u20AC","rejection at $","rejection at \u20AC","pauses above $","pauses below $",
                  "revisit $","slumps above $"]
Market_Analysis = ['aktien', 'aktie', 'stock', 'stocks', 'stockmarket', 'aktien:',
                   'rating', 'markt', 'märkte', 'kurs', 'kurse', 'kursgewinn', 'kurssprung',
                   'kursgewinne', 'kursverluste', 'kursverlust', 'kursminus', 'daxaktien'
                   'sell', 'buy', 'dow jones', 'dax', 's&p500', 's&p 500', 'dji', 'bull'
                   'short', 'aktienbewertung', 'aktienbewertungen', 'kaufempfehlung', 'bear',
                   'halteempfehlung', 'verkaufsempfehlung', 'boerse.de', 'aktionär', '"hold"',
                   'preisprognose', 'analyst', 'analysts', 'preisprognosen', 'share', 'shares',
                   'kurssturz', 'aktienmarkt', 'kursziel', 'aktie:', 'preisziel', 'kursplus',
                   'raised its price', 'aktienrückkauf', 'aktienrückkäufe', 'marktanalyse',
                   'market', 'markets', 'aktienverlust', 'aktienverluste', 'aktiencheck', 
                   'shareholder', 'shareholders', 'aktionäre', 'preisrally', 'isin', '"sell"',
                   '"buy"', 'aktienkurs', 'aktienkurse', 'aktiennews', 'bärenmarkt', 'bullenmarkt',
                   'estimatekurse', 'chartanalyse', 'chart analysis', 'preiskorrektur', 'price']

# %%
import pandas as pd

data = [Legal_documents, Warnings_Enforcements_Sanctions,
        Science_papers, Reports, Official_statements,
        Guidelines, Press_releases, Personnel_changes,
        Market_Analysis]

df = pd.DataFrame()

for i, category in enumerate(data):
    df[str(i)] = pd.Series(category)

df.columns = ["legal","sanctions","papers","reports",
             "statements","guidelines","press",
             "personnel","market"]

df
# Out:
#                               legal                    sanctions  \
# 0              parliamentary decree       launches investigation
# 1                        Richtlinie            sanktionsmaßnahme
# 2               governmental ruling         is not authorised to
# 3      municipal regulatory measure                      prozess
# 4          parliamentary regulation  disziplinarische geldstrafe
# ..                              ...                          ...
# 283         presidential regulatory                          NaN
# 284  legislative regulatory measure                          NaN
# 285                      regulation                          NaN
# 286               legal stipulation                          NaN
# 287                       directive                          NaN
#
#                                   papers  \
# 0                  Forschungspublikation
# 1          wissenschaftliche Zeitschrift
# 2         wissenschaftliche Präsentation
# ...

# %%
df.to_csv("../../reghub_cats_updated.csv")
